# %%
# !git config --global user.email "rodri673@gmail.com"
# !git config --global user.name "dehonidas9"

# %%
from google.colab import userdata
token = userdata.get('TFG_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Proyecto_Audio
# Out:
# /content/drive/MyDrive/Proyecto_Audio

# %%
# !git config pull.rebase false

# %%
# !git pull https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main --no-edit
# Out:
# From https://github.com/dehonidas9/TFG_restauracion_audio
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .
# !git commit -m "Corrección de errores app modelo deepfilternet, funciona con vooz de niña, no era el modelo si no la entrada de datos "
# !git push https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main
# Out:
# [main 6612a0c] Actualizo diary a 31/07/2026 y añado nuevos archivos al drive, empiezo app
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite notebooks/01_DeepFilterNet_3_6.ipynb (90%)
#  rewrite notebooks/commit_push.ipynb (96%)
# Enumerating objects: 47, done.
# Counting objects: 100% (44/44), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (38/38), done.
# Writing objects: 100% (39/39), 19.96 KiB | 252.00 KiB/s, done.
# Total 39 (delta 19), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (19/19), completed with 4 local objects.
# To https://github.com/dehonidas9/TFG_restauracion_audio.git
#    334dd69..6612a0c  main -> main
