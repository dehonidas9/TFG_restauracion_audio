# %%
# !git config --global user.email "rodri673@gmail.com"
# !git config --global user.name "dehonidas9"

# %%
from google.colab import userdata
token = userdata.get('TFG_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Proyecto_Audio
# Out:
# /content/drive/MyDrive/Proyecto_Audio

# %%
# !git config pull.rebase false

# %%
# !git pull https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main --no-edit
# Out:
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 12 (delta 9), reused 0 (delta 0), pack-reused 0 (from 0)
# Unpacking objects: 100% (12/12), 6.81 KiB | 5.00 KiB/s, done.
# From https://github.com/dehonidas9/TFG_restauracion_audio
#  * branch            main       -> FETCH_HEAD
# Updating cdb915a..c2aa589

# %%
# !git add .
# !git commit -m "Incorporación a la app de los modelos MP-SEnet y Voice"
# !git push https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main
# Out:
# [main cdb915a] Corrección de errores app modelo deepfilternet, funciona con vooz de niña, no era el modelo si no el formato de la entrada de datos
#  4 files changed, 137 insertions(+), 136 deletions(-)
#  rewrite notebooks/01_DeepFilterNet_3_6.ipynb (97%)
#  rewrite notebooks/commit_push.ipynb (96%)
# Enumerating objects: 17, done.
# Counting objects: 100% (17/17), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 3.66 KiB | 170.00 KiB/s, done.
# Total 9 (delta 7), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (7/7), completed with 7 local objects.
# To https://github.com/dehonidas9/TFG_restauracion_audio.git
#    6612a0c..cdb915a  main -> main
