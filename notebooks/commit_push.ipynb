# %%
# !git config --global user.email "rodri673@gmail.com"
# !git config --global user.name "dehonidas9"

# %%
from google.colab import userdata
token = userdata.get('TFG_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Proyecto_Audio
# Out:
# /content/drive/MyDrive/Proyecto_Audio

# %%
# !git config pull.rebase false

# %%
# !git pull https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main --no-edit
# Out:
# From https://github.com/dehonidas9/TFG_restauracion_audio
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
# !git add .
# !git commit -m "Incorporación a la app de Audio SR y , búsqueda de audios adecuados para los problemas de separación de fuentes, banda reducida, ruido"
# !git push https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main
# Out:
# [main 89cbeea] Incorporación a la app de los modelos MP-SEnet y Voicefixer, corrección de bugs entre librerías y token de HF
#  4 files changed, 216 insertions(+), 23 deletions(-)
#  create mode 100644 gradio_app/tfg_models/declipping.py
#  create mode 100644 gradio_app/tfg_models/dereverb.py
#  rewrite notebooks/commit_push.ipynb (60%)
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (9/9), 5.07 KiB | 178.00 KiB/s, done.
# Total 9 (delta 5), reused 0 (delta 0), pack-reused 0
