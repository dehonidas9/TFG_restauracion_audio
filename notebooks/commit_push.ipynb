# %%
# !git config --global user.email "rodri673@gmail.com"
# !git config --global user.name "dehonidas9"

# %%
from google.colab import userdata
token = userdata.get('TFG_TOKEN')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Proyecto_Audio
# Out:
# /content/drive/MyDrive/Proyecto_Audio

# %%
# !git add .
# !git commit -m "Actualizo diary a 31/07/2026 y aañado nuevos archivos al drive empiezo app"
# !git push https://{token}@github.com/dehonidas9/TFG_restauracion_audio.git main
# Out:
# [main 0eea168] Actualizo diary a 31/07/2026 y aañado nuevos archivos al drive empiezo app
#  15 files changed, 721 insertions(+), 2 deletions(-)
#  create mode 100644 gradio_app/Dockerfile
#  create mode 100644 gradio_app/README.md
#  create mode 100644 gradio_app/app.py
#  create mode 100644 gradio_app/requirements.txt
#  create mode 100644 gradio_app/tfg_audio_utils/__init__.py
#  create mode 100644 gradio_app/tfg_audio_utils/audio_utils_baselines_clasicos.py
#  create mode 100644 gradio_app/tfg_audio_utils/audio_utils_funcionescomunes.py
#  create mode 100644 gradio_app/tfg_audio_utils/audio_utils_memoria_GPU.py
#  create mode 100644 gradio_app/tfg_audio_utils/audio_utils_metricas_no_intrusivas.py
#  create mode 100644 gradio_app/tfg_audio_utils/audio_utils_metricas_ref.py
#  create mode 100644 gradio_app/tfg_models/__init__.py
#  create mode 100644 gradio_app/tfg_models/denoising.py
#  create mode 100644 gradio_app/tfg_models/model_manager.py
#  rewrite notebooks/01_DeepFilterNet_3_6.ipynb (98%)
#  rewrite notebooks/commit_push.ipynb (94%)
# To https://github.com/dehonidas9/TFG_restauracion_audio.git
#  ! [rejected]        main -> main (fetch first)
# error: failed to push some refs to 'https://github.com/dehonidas9/TFG_restauracion_audio.git'
# hint: Updates were rejected because the remote contains work that you do
# hint: not have locally. This is usually caused by another repository pushing
# hint: to the same ref. You may want to first integrate the remote changes
# hint: (e.g., 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.
